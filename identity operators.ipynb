# %%
c=[1,3,5,7,9]
d=[1,3,5,7,9]
print(c==d)
print(c is d)
x=True
if type (x) is int:
    print("data type is integer")
elif type (x) is str:
    print("data type is string")
elif type (x) is float:
    print("data type is float")
else:
    print("boolean")
# Out:
# True
# False
# boolean
