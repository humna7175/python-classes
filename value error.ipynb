# %%
try:
    number=int(input("enter your number:"))
    print(number)
    print("normal scenario excecuted")
except ValueError:
    print("the user should type a number not some letter,it is an exception")
# Out:
# enter your number: humna
# the user should type a number not some letter,it is an exception
