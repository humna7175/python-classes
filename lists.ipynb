# %%
numbers=[0,1,2,3,4,5]
print(numbers)

print("length is:",len(numbers))
list1=["p","y","t","h","o","n"]

print(list1[3])
print(list1[5])

print(list1[3:6])
# Out:
# [0, 1, 2, 3, 4, 5]
# length is: 6
# h
# n
# ['h', 'o', 'n']
