# %%
#ask for todays temperature
tem=int(input("enter your todays temperature:"))
#decide between out door and indoor activities
if tem< 20:
     activities="indoor reading"
     print("it is cool today.")
     print("do",activities)
else:
     activities="outdoor play"
     print("it is warm today")
     print("do",activities)
# Out:
# enter your todays temperature: 15
# it is cool today.
# do indoor reading
