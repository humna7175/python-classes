# %%
## balance=5000
pin=7175
while True:
    entered_pin=int(input("enter your pin:"))
    if entered_pin==pin:
        print("access granted")
        while True:
            print("_ _ _ _ATM MENU_ _ _ _")
            print("1.check balance")
            print("2.deposite")
            print("3.withdrawl")
            print("exit")
            choice=int(input("enter your choice:"))
            if choice==1:
                print("balance is:",balance)
            elif choice==2:
                add=int(input("enter your ammount to deposite:"))
                balance=balance+add
                print("ammount added")
            elif choice==3:
                minus=int(input("enter your ammount to withdrawl:"))
                balance=balance-minus
                print("ammount withdrawn")
            else:
                print("you exit the banking system")
                break
                
             
                
            
                     
    
    else:
        print("invaild")
# Out:
# enter your pin: 7175
# access granted
# _ _ _ _ATM MENU_ _ _ _
# 1.check balance
# 2.deposite
# 3.withdrawl
# exit
# enter your choice: 3
# enter your ammount to withdrawl: 2000
# ammount withdrawn
# _ _ _ _ATM MENU_ _ _ _
# 1.check balance
# 2.deposite
# 3.withdrawl
# exit
# enter your choice: 1
# balance is: 3000
# _ _ _ _ATM MENU_ _ _ _
# 1.check balance
# 2.deposite
# 3.withdrawl
# exit
