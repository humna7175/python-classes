# %%
print("school week planner")
print("you have to answer 3 questions")
weather=input("sunny/rainy:")
homework=input("is your homework done?(yes/no)")
day=input("monday to sunday:")
if weather=="sunny":
    print("play outside")
else:
    print(weather,":stay inside")
# Out:
# school week planner
# you have to answer 3 questions
