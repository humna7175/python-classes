# %%
n1="hamna"
print(n1)
# Out:
# hamna

# %%
print("welcome to the websites",n1)
# Out:
# welcome to the websites hamna

# %%
hobby="martial arts"
print(hobby)
# Out:
# martial arts

# %%
print("my hobby is",hobby)
# Out:
# my hobby is martial arts
