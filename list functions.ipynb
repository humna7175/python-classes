# %%
numbers=[22,9,30,50,75]
print("orignal numbers:",numbers)

numbers.append(67)
print("numbers after appendent:",numbers)

numbers.extend([22,9,7,67,2])
print("numbers after extanding:",numbers)

print(min(numbers))
print(max(numbers))
# Out:
# orignal numbers: [22, 9, 30, 50, 75]
# numbers after appendent: [22, 9, 30, 50, 75, 67]
# numbers after extanding: [22, 9, 30, 50, 75, 67, 22, 9, 7, 67, 2]
# 2
# 75
