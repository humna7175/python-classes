# %%
day=input("enter your day:")
if day=="saturday" or day=="sunday":
    print("its your weekend")
elif day=="monday":
    print("its your first day of week")
elif day=="friday":
    print("its your last day of week")
elif day=="tuesday" or day=="wednesday" or day=="thursday":
    print("reguler days of week")
else:
    print("pls type a valid day")
# Out:
# enter your day: monday
# its your first day of week
