# %%
n=int(input("enter the number of rows you want:"))
for i in range(n):
    for h in range(n):
        print("*",end="")
    print()
# Out:
# enter the number of rows you want: 5
# *****
# *****
# *****
# *****
# *****
