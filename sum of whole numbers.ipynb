# %%
sum=0
for i in range(1,6):
    num=int(input("enter your number:"))
    sum=num+sum
print("sum is:",sum)
# Out:
# enter your number: 9
# enter your number: 22
# enter your number: 2
# enter your number: 4
# enter your number: 25
# sum is: 62
