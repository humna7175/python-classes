# %%
costprice=int(input("enter costprice"))
sellprice=int(input("enter sellprice"))
diff=sellprice-costprice
if diff>0:
    print("profit",diff)
else:
    print("loss",diff)
# Out:
# enter costprice 67
# enter sellprice 76
# profit 9
