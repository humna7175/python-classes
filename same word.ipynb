# %%
list1=["Hamna","Dua","Rabia","Jannat","Arfa"]
list2=["Ayesha","Arfa","Hamna","Bisma","Uswa"]
same=[]

for i in list1:
    if i in list2:
        same.append(i)
print(same)
# Out:
# ['Hamna', 'Arfa']
