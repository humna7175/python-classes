# %%
def greet():
    print("welcome to the website")

greet()
# Out:
# welcome to the website

# %%
def greet2(name):
    print("welcome",name,"to the website")
    
greet2("humna")
greet2("dua")
# Out:
# welcom humna to the website
# welcom dua to the website

# %%
name=input("enter your name:")
greet2(name)
# Out:
# enter your name: humna
# welcom humna to the website
