# %%
n=int(input("enter your number:"))
for i in range(n):
    for d in range(i+1):
        print("*",end="")
    print()
# Out:
# enter your number: 7
# *
# **
# ***
# ****
# *****
# ******
# *******
