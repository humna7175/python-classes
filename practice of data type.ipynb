# %%
name="hamna"
age=13

print("name:",name)
print("data type of name is:",type(name))

print("age:",age)
print("data type of name is:",type(age))

n1="hamna"
n2="dua"

print("n1:",n1)
print("data type of n1 is:",type(n1))

print("n2:",n2)
print("data type of n2 is:",type(n2))
# Out:
# name: hamna
# data type of name is: <class 'str'>
# age: 13
# data type of name is: <class 'int'>
# n1: hamna
# data type of n1 is: <class 'str'>
# n2: dua
# data type of n2 is: <class 'str'>
