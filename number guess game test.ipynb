# %%
print("this is the number guss game guss random betwwen 1,20")
import random
num=random.randint(1,20)
while True:
    guess=int(input("enter the number"))
    if guess==num:
        print("your guess is right")
        break
    else:
        print("wrong")
        
    if num % 2==0:
        print("hint:the number is even")
    else:
        print("hint:the number is odd")
# Out:
# this is the number guss game guss random betwwen 1,20
# enter the number 2
# wrong
# hint:the number is odd
# enter the number 3
# wrong
# hint:the number is odd
# enter the number 7
# wrong
# hint:the number is odd
# enter the number 9
# wrong
# hint:the number is odd
# enter the number 11
# your guess is right
