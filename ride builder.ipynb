# %%
## print("welcome to ride builder")
choice=int(input("1.bike \n 2.car \n choose:"))
if choice==1:
    bike=int(input("1.bugati \n 2.bulit \n choose:"))
    if bike==1:
        print("you slected bugati")
    elif bike==2:
        print("you slected bulit")
    else:
        print("not available")
if choice==2:
    car=int(input("1.porch \n 2.bmw \n choose:"))
    if car==1:
        print("you slected porch")
    elif car==2:
        print("you slected bmw")
    else:
        print("not available")
# Out:
# 1.bike
#  2.car
#  choose: 2
# 1.porch
#  2.bmw
#  choose: 2
# you slected bmw
